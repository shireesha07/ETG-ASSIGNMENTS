# %%
items={  101:{"name":"drinks",        "price":"48",       "quantity":"30",       "discount":"10",      "expiry-date":"10-04-2023"},
  102:{"name":"chochalate",    "price":"10",       "quantity":"60",       "discount":"0",       "expiry-date":" 17-09-2024"},
  103:{"name":"cake",          "price":"300",      "quantity":"30",       "discount":"10",      "expiry-date":"1day"},
  104:{"name":"biscuits",      "price":"50",       "quantity":"67",       "discount":"2",       "expiry-date":"10-12-2021"},
  105:{"name":" muffins",      "price":"40",       "quantity":"40",       "discount":"3",       "expiry-date":"10-09-2021"},
  106:{"name":"pizza",         "price":"100",      "quantity":"33",       "discount":"4",       "expiry-date":"1day"},
  107:{"name":"sweets",        "price":"250",      "quantity":"34",       "discount":"10",      "expiry-date":"12-04-2021"},
  108:{"name":"cookies",       "price":"100",      "quantity":"45",       "discount":"5",       "expiry-date":"10-08-2021"},
  109:{"name":"bread",         "price":"22",       "quantity":"30",       "discount":"4",       "expiry-date":"13-10-2023"},
  110:{"name":"veg puff",      "price":"25",       "quantity":"30",       "discount":"2",       "expiry-date":"12-02-2021"},
  111:{"name":"egg puff",      "price":"30",       "quantity":"30",       "discount":"10",      "expiry-date":"18-04-2021"},
  112:{"name":"ice-cream",     "price":"120",      "quantity":"45",       "discount":"15",      "expiry-date":"30-05-2021"},
  113:{"name":"chips",         "price":"20",       "quantity":"56",       "discount":"0",       "expiry-date":"12-04-2021"},
  114:{"name":"pastry",        "price":"45",       "quantity":"45",       "discount":"10",      "expiry-date":"10-05-2021"},
  115:{"name":"cupcakes",      "price":"30",       "quantity":"20",       "discount":"2",       "expiry-date":"15-08-2021"},
  116:{"name":"rusktoast",     "price":"60",       "quantity":"32",       "discount":"3",       "expiry-date":"09-02-2022"},
  117:{"name":"milk",          "price":"25",       "quantity":"30",       "discount":"10",      "expiry-date":"08-09-2021"},
  118:{"name":"papad",         "price":"30",       "quantity":"20",       "discount":"2",       "expiry-date":"10-4-2023"},
  119:{"name":"honey",         "price":"75",       "quantity":"40",       "discount":"10",      "expiry-date":"16-09-2023"},
  120:{"name":"paneer",        "price":"79",       "quantity":"43",       "discount":"4",       "expiry-date":"09-05-2021"},
  121:{"name":"dry-fruits",    "price":"250",      "quantity":"54",       "discount":"5",       "expiry-date":"08-10-2023"},
  122:{"name":"cheese",        "price":"78",       "quantity":"32",       "discount":"2",       "expiry-date":"14-06-2021"},
  123:{"name":"sandwich",      "price":"48",       "quantity":"30",       "discount":"2",       "expiry-date":"08-05-2021"},
  124:{"name":"maggi",         "price":"30",       "quantity":"30",       "discount":"3",       "expiry-date":"10-04-2022"},
  125:{"name":"spices",        "price":"89",       "quantity":"45",       "discount":"14",      "expiry-date":"15-06-2023"},
  126:{"name":"oil",           "price":"130",      "quantity":"67",       "discount":"10",      "expiry-date":"20-07-2023"},
  127:{"name":"salt",          "price":"15",       "quantity":"55",       "discount":"2",       "expiry-date":"25-06-2022"},
  128:{"name":"coffee",        "price":"45",       "quantity":"25",       "discount":"2",       "expiry-date":"02-05-2021"},
  129:{"name":"popcorn",       "price":"56",       "quantity":"30",       "discount":"6",       "expiry-date":"09-02-2021"},
  130:{"name":"soya-sauce",    "price":"50",       "quantity":"30",       "discount":"5",       "expiry-date":"19-06-2022"}  }

# %%
items
# Out:
# {101: {'name': 'drinks',
#   'price': '48',
#   'quantity': '30',
#   'discount': '10',
#   'expiry-date': '10-04-2023'},
#  102: {'name': 'chochalate',
#   'price': '10',
#   'quantity': '60',
#   'discount': '0',
#   'expiry-date': ' 17-09-2024'},
#  103: {'name': 'cake',
#   'price': '300',
#   'quantity': '30',
#   'discount': '10',
#   'expiry-date': '1day'},
#  104: {'name': 'biscuits',
#   'price': '50',
#   'quantity': '67',
#   'discount': '2',
#   'expiry-date': '10-12-2021'},
#  105: {'name': ' muffins',
#   'price': '40',
#   'quantity': '40',
#   'discount': '3',
#   'expiry-date': '10-09-2021'},
#  106: {'name': 'pizza',
#   'price': '100',
#   'quantity': '33',
#   'discount': '4',
#   'expiry-date': '1day'},
#  107: {'name': 'sweets',
#   'price': '250',
#   'quantity': '34',
#   'discount': '10',
#   'expiry-date': '12-04-2021'},
#  108: {'name': 'cookies',
#   'price': '100',
#   'quantity': '45',
#   'discount': '5',
#   'expiry-date': '10-08-2021'},
# ...

# %%
import json

# %%
js=json.dumps(items)

# %%
js
# Out:
# '{"101": {"name": "drinks", "price": "48", "quantity": "30", "discount": "10", "expiry-date": "10-04-2023"}, "102": {"name": "chochalate", "price": "10", "quantity": "60", "discount": "0", "expiry-date": " 17-09-2024"}, "103": {"name": "cake", "price": "300", "quantity": "30", "discount": "10", "expiry-date": "1day"}, "104": {"name": "biscuits", "price": "50", "quantity": "67", "discount": "2", "expiry-date": "10-12-2021"}, "105": {"name": " muffins", "price": "40", "quantity": "40", "discount": "3", "expiry-date": "10-09-2021"}, "106": {"name": "pizza", "price": "100", "quantity": "33", "discount": "4", "expiry-date": "1day"}, "107": {"name": "sweets", "price": "250", "quantity": "34", "discount": "10", "expiry-date": "12-04-2021"}, "108": {"name": "cookies", "price": "100", "quantity": "45", "discount": "5", "expiry-date": "10-08-2021"}, "109": {"name": "bread", "price": "22", "quantity": "30", "discount": "4", "expiry-date": "13-10-2023"}, "110": {"name": "veg puff", "price": "25"
# ...

# %%
items
# Out:
# {101: {'name': 'drinks',
#   'price': '48',
#   'quantity': '30',
#   'discount': '10',
#   'expiry-date': '10-04-2023'},
#  102: {'name': 'chochalate',
#   'price': '10',
#   'quantity': '60',
#   'discount': '0',
#   'expiry-date': ' 17-09-2024'},
#  103: {'name': 'cake',
#   'price': '300',
#   'quantity': '30',
#   'discount': '10',
#   'expiry-date': '1day'},
#  104: {'name': 'biscuits',
#   'price': '50',
#   'quantity': '67',
#   'discount': '2',
#   'expiry-date': '10-12-2021'},
#  105: {'name': ' muffins',
#   'price': '40',
#   'quantity': '40',
#   'discount': '3',
#   'expiry-date': '10-09-2021'},
#  106: {'name': 'pizza',
#   'price': '100',
#   'quantity': '33',
#   'discount': '4',
#   'expiry-date': '1day'},
#  107: {'name': 'sweets',
#   'price': '250',
#   'quantity': '34',
#   'discount': '10',
#   'expiry-date': '12-04-2021'},
#  108: {'name': 'cookies',
#   'price': '100',
#   'quantity': '45',
#   'discount': '5',
#   'expiry-date': '10-08-2021'},
# ...

# %%
type(js)
# Out:
# str

# %%
type(items)
# Out:
# dict

# %%
fd=open("items.json",'w')
fd.write(js)
fd.close()

# %%
fd=open("items.json",'r')
txt=fd.read()
fd.close()

# %%
txt
# Out:
# '{"101": {"name": "drinks", "price": "48", "quantity": "30", "discount": "10", "expiry-date": "10-04-2023"}, "102": {"name": "chochalate", "price": "10", "quantity": "60", "discount": "0", "expiry-date": " 17-09-2024"}, "103": {"name": "cake", "price": "300", "quantity": "30", "discount": "10", "expiry-date": "1day"}, "104": {"name": "biscuits", "price": "50", "quantity": "67", "discount": "2", "expiry-date": "10-12-2021"}, "105": {"name": " muffins", "price": "40", "quantity": "40", "discount": "3", "expiry-date": "10-09-2021"}, "106": {"name": "pizza", "price": "100", "quantity": "33", "discount": "4", "expiry-date": "1day"}, "107": {"name": "sweets", "price": "250", "quantity": "34", "discount": "10", "expiry-date": "12-04-2021"}, "108": {"name": "cookies", "price": "100", "quantity": "45", "discount": "5", "expiry-date": "10-08-2021"}, "109": {"name": "bread", "price": "22", "quantity": "30", "discount": "4", "expiry-date": "13-10-2023"}, "110": {"name": "veg puff", "price": "25"
# ...

# %%
items=json.loads(txt)

# %%
items
# Out:
# {'101': {'name': 'drinks',
#   'price': '48',
#   'quantity': '30',
#   'discount': '10',
#   'expiry-date': '10-04-2023'},
#  '102': {'name': 'chochalate',
#   'price': '10',
#   'quantity': '60',
#   'discount': '0',
#   'expiry-date': ' 17-09-2024'},
#  '103': {'name': 'cake',
#   'price': '300',
#   'quantity': '30',
#   'discount': '10',
#   'expiry-date': '1day'},
#  '104': {'name': 'biscuits',
#   'price': '50',
#   'quantity': '67',
#   'discount': '2',
#   'expiry-date': '10-12-2021'},
#  '105': {'name': ' muffins',
#   'price': '40',
#   'quantity': '40',
#   'discount': '3',
#   'expiry-date': '10-09-2021'},
#  '106': {'name': 'pizza',
#   'price': '100',
#   'quantity': '33',
#   'discount': '4',
#   'expiry-date': '1day'},
#  '107': {'name': 'sweets',
#   'price': '250',
#   'quantity': '34',
#   'discount': '10',
#   'expiry-date': '12-04-2021'},
#  '108': {'name': 'cookies',
#   'price': '100',
#   'quantity': '45',
#   'discount': '5',
# ...
